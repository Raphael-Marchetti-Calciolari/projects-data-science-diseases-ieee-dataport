# %% [markdown]
# <a href="https://colab.research.google.com/github/Raphael-Marchetti-Calciolari/projects-data-science-diseases-ieee-dataport/blob/main/Projeto_Ciencia_de_Dados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Importação das bibliotecas utilizadas no projeto

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Carregamento das bases de dados
#
# > ## [Base de dados de doenças cardíacas](https://ieee-dataport.org/open-access/heart-disease-dataset-comprehensive)
#
# >> <p align= "justify">Este conjunto de dados de doenças cardíacas foi feito a partir da combinação de 5 conjuntos de dados populares de doenças cardíacas já disponíveis de forma independente. Este conjunto de dados é combinado em 11 características comuns, o que o torna o maior conjunto de dados de doenças cardíacas disponível até agora para fins de pesquisa. Os cinco conjuntos de dados usados para sua criação foram:</p>
#
# >>- Cleveland
# >>- húngaro
# >>- Suíça
# >>- Long Beach VA
# >>- Conjunto de dados Statlog (coração).
#
# >>### Colunas:
# >>- **age**: years
# >>- **sex**: male, female
# >>- **chest paint type**:
# >>>1. typical angina
# >>>2. atypicalangina
# >>>3. non-anginal pain
# >>>4. asymptomatic
# >>- **resting blood pressure**: in mm/Hg
# >>- **serum cholesterol**: in mg/dl
# >>- **fasting blood sugar**: fasting blood sugar > 120 mg/dl
# >>- **resting eletrocardiogram results**:
# >>>1. normal
# >>>2. having ST-T wave abnormality
# >>>3. showing probable or define left ventricular
# >>- **maximum heart rate achieved**: 71-202
# >>- **exercise induced angina**: True, False
# >>- **oldpeak = ST**: depression
# >>- **the slope ok the peak exercise ST segment**:
# >>>1. upsloping
# >>>2. flat
# >>>3. downsloping
# >>- **class**:
# >>>1. heart disease
# >>>2. normal
#
# >>OBS: ST slope represents the beginning of ventricular repolarization.
# > ## [Base de dados de cancêr de mama](https://ieee-dataport.org/open-access/seer-breast-cancer-data)
#
# >> <p align= "justify">Este conjunto de dados de pacientes com câncer de mama foi obtido da atualização de novembro de 2017 do Programa SEER do NCI, que fornece informações sobre estatísticas populacionais de câncer. O conjunto de dados envolveu pacientes do sexo feminino com carcinoma lobular e ducto infiltrante diagnosticados em 2006-2010. Pacientes com tamanho de tumor desconhecido, LNs regionais examinados, LNs regionais positivos e pacientes cujos meses de sobrevida foram inferiores a 1 mês foram excluídos.</p>
#
# >>### Colunas:
# >>- **AGE**: years
# >>- **RACE**: race recode
# >>- **MARITAL STATUS**:
# >>>1. Single
# >>>2. Married
# >>>3. Separated
# >>>4. Divorced
# >>>5. Widowed
# >>- **T STAGE**:
# >>>1. T1
# >>>2. T2
# >>>3. T3
# >>>4. T4
# >>- **N STAGE**:
# >>>1. N1
# >>>2. N2
# >>>3. N3
# >>- **6TH STAGE**:
# >>>1. IIA
# >>>2. IIB
# >>>3. IIIA
# >>>4. IIIB
# >>>5. IIIC
# >>- **GRADE**:
# >>>1. Grade I well differentiated
# >>>2. Grade II moderately differentiated
# >>>3. Grade III poorly differentiated
# >>>4. Grade IV undifferentiated
# >>- **A STAGE**:
# >>>1. Regional
# >>>2. Distant
# >>- **TUMOR SIZE**:
# >>- **ESTROGEN STATUS**: TRUE, FALSE
# >>- **PROGESTERONE STATUS**: TRUE, FALSE
# >>- **REGIONAL NODES EXAMINED**:
# >>- **REGIONAL NODES POSITIVE**:
# >>- **SURVIVAL MONTHS**:
# >>- **STATUS**:
# >>>1. Alive
# >>>2. Dead
#
# >## [Base de dados de diabetes](https://data.mendeley.com/datasets/wj9rwkp9c2/1)
#
# >><p align= "justify">Os dados foram coletados da sociedade iraquiana, sendo adquiridos do laboratório do Medical City Hospital, do Centro Especializado de Endocrinologia e do Hospital Universitário Diabetes-Al-Kindy. Os dados consistem em informações médicas e análises laboratoriais.</p>
#
# >>### Colunas
# >>- **Age**
# >>- **Gender**
# >>- **CR**: Creatinine ratio
# >>- **BMI**: Body Mass Index
# >>- **Urea**: Urea
# >>- **Chol**: Cholesterol
# >>- **LDL**: LDL Cholesterol
# >>- **VLDL**: VLDL Cholesterol
# >>- **TG**: Triglycerides Cholesterol
# >>- **HDL**: HDL Cholesterol
# >>- **HBA1C**: Average blood sugar
# >>- **Class**:
# >>>1. Y
# >>>2. N
# >>>3. P

# %%
diabetes_df = pd.read_csv('https://raw.githubusercontent.com/Raphael-Marchetti-Calciolari/projects-data-science-diseases-ieee-dataport/main/datasets/DIABETES%20DISEASE%20UPDATED%20DATASET/Dataset%20of%20Diabetes%20.csv')
heart_disease_df = pd.read_csv('https://raw.githubusercontent.com/Raphael-Marchetti-Calciolari/projects-data-science-diseases-ieee-dataport/main/datasets/HEART%20DISEASE%20DATASET/heart_statlog_cleveland_hungary_final.csv')
breast_cancer_df = pd.read_csv('https://raw.githubusercontent.com/Raphael-Marchetti-Calciolari/projects-data-science-diseases-ieee-dataport/main/datasets/SEER%20BREAST%20CANCER%20DATA/SEER%20Breast%20Cancer%20Dataset%20.csv')

# %% [markdown]
# # Visualização dos dados

# %%
diabetes_df.head()
# Out:
#     ID  No_Pation Gender  AGE  Urea  Cr  HbA1c  Chol   TG  HDL  LDL  VLDL  \
# 0  502      17975      F   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5
# 1  735      34221      M   26   4.5  62    4.9   3.7  1.4  1.1  2.1   0.6
# 2  420      47975      F   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5
# 3  680      87656      F   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5
# 4  504      34223      M   33   7.1  46    4.9   4.9  1.0  0.8  2.0   0.4
#
#     BMI CLASS
# 0  24.0     N
# 1  23.0     N
# 2  24.0     N
# 3  24.0     N
# 4  21.0     N

# %%
heart_disease_df.head()
# Out:
#    age  sex  chest pain type  resting bp s  cholesterol  fasting blood sugar  \
# 0   40    1                2           140          289                    0
# 1   49    0                3           160          180                    0
# 2   37    1                2           130          283                    0
# 3   48    0                4           138          214                    0
# 4   54    1                3           150          195                    0
#
#    resting ecg  max heart rate  exercise angina  oldpeak  ST slope  target
# 0            0             172                0      0.0         1       0
# 1            0             156                0      1.0         2       1
# 2            1              98                0      0.0         1       0
# 3            0             108                1      1.5         2       1
# 4            0             122                0      0.0         1       0

# %%
breast_cancer_df.head()
# Out:
#    Age                                              Race   \
# 0   43  Other (American Indian/AK Native, Asian/Pacifi...
# 1   47  Other (American Indian/AK Native, Asian/Pacifi...
# 2   67                                              White
# 3   46                                              White
# 4   63                                              White
#
#                    Marital Status  Unnamed: 3 T Stage  N Stage 6th Stage  \
# 0  Married (including common law)         NaN       T2      N3      IIIC
# 1  Married (including common law)         NaN       T2      N2      IIIA
# 2  Married (including common law)         NaN       T2      N1       IIB
# 3                        Divorced         NaN       T1      N1       IIA
# 4  Married (including common law)         NaN       T2      N2      IIIA
#
#                                  Grade   A Stage  Tumor Size Estrogen Status  \
# 0  Moderately differentiated; Grade II  Regional          40        Positive
# ...

# %% [markdown]
# # Transformação

# %% [markdown]
# ## Tratando os dados do dataframe de diabetes

# %% [markdown]
# ### Ajustando valores

# %%
diabetes_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ID         1000 non-null   int64
#  1   No_Pation  1000 non-null   int64
#  2   Gender     1000 non-null   object
#  3   AGE        1000 non-null   int64
#  4   Urea       1000 non-null   float64
#  5   Cr         1000 non-null   int64
#  6   HbA1c      1000 non-null   float64
#  7   Chol       1000 non-null   float64
#  8   TG         1000 non-null   float64
#  9   HDL        1000 non-null   float64
#  10  LDL        1000 non-null   float64
#  11  VLDL       1000 non-null   float64
#  12  BMI        1000 non-null   float64
#  13  CLASS      1000 non-null   object
# dtypes: float64(8), int64(4), object(2)
# memory usage: 109.5+ KB

# %%
# N = não diabético, P = possivel diabético, Y = diabético
diabetes_df['CLASS'] = (diabetes_df['CLASS']
                          .replace('N ', 'N')
                          .replace('Y ', 'Y'))
diabetes_df['CLASS'].unique()
# Out:
# array(['N', 'P', 'Y'], dtype=object)

# %%
# F = female, M = male
diabetes_df['Gender'] = diabetes_df['Gender'].replace('f', 'F')
diabetes_df['Gender'].unique()
# Out:
# array(['F', 'M'], dtype=object)

# %% [markdown]
# ### Removendo identificadores

# %%
diabetes_df = diabetes_df.drop(columns=['ID', 'No_Pation']).reset_index(drop=True)

# %% [markdown]
# ### Removendo duplicatas

# %%
diabetes_df.shape
# Out:
# (1000, 12)

# %%
diabetes_df = diabetes_df.drop_duplicates()
diabetes_df.shape # sem duplicatas
# Out:
# (826, 12)

# %% [markdown]
# ### Removendo valores nulos

# %%
diabetes_df.isnull().sum()
# Out:
# Gender    0
# AGE       0
# Urea      0
# Cr        0
# HbA1c     0
# Chol      0
# TG        0
# HDL       0
# LDL       0
# VLDL      0
# BMI       0
# CLASS     0
# dtype: int64

# %% [markdown]
# ### Removendo números zerados onde não faz sentido

# %%
diabetes_numeric_columns = []
for column in diabetes_df.columns:
  if (diabetes_df[column].dtype in ['int64', 'float64']): diabetes_numeric_columns.append(column)
print(diabetes_numeric_columns)
# Out:
# ['AGE', 'Urea', 'Cr', 'HbA1c', 'Chol', 'TG', 'HDL', 'LDL', 'VLDL', 'BMI']

# %%
print(f'\n3 smallest data')
display(diabetes_df.nsmallest(3, columns=diabetes_numeric_columns))
print(f'\n3 largest data')
display(diabetes_df.nlargest(3, columns=diabetes_numeric_columns))
# Out:
# 3 smallest data
#     Gender  AGE  Urea  Cr  HbA1c  Chol   TG  HDL  LDL  VLDL   BMI CLASS
# 979      F   20   4.6  70    9.6   4.1  1.8  1.0  2.3   0.8  30.0     Y
# 86       F   25  10.0  35    4.0   4.3  3.5  0.8  1.3   0.8  22.0     N
# 1        M   26   4.5  62    4.9   3.7  1.4  1.1  2.1   0.6  23.0     N
# 3 largest data
#     Gender  AGE  Urea   Cr  HbA1c  Chol   TG  HDL  LDL  VLDL   BMI CLASS
# 617      F   79   5.2   54    9.2   6.4  3.0  1.1  4.1   1.3  30.0     Y
# 382      M   77   6.2   99    7.2   3.2  1.1  0.8  2.0   0.5  29.0     Y
# 93       F   77   5.0  106    5.4   3.9  2.1  1.2  4.2   1.1  24.0     N

# %%
diabetes_df.min()
# Out:
# Gender       F
# AGE         20
# Urea       0.5
# Cr           6
# HbA1c      0.9
# Chol       0.0
# TG         0.3
# HDL        0.2
# LDL        0.3
# VLDL       0.1
# BMI       19.0
# CLASS        N
# dtype: object

# %% [markdown]
# ### Visualização final dos dados

# %%
display(diabetes_df)
# Out:
#     Gender  AGE  Urea   Cr  HbA1c  Chol   TG  HDL  LDL  VLDL   BMI CLASS
# 0        F   50   4.7   46    4.9   4.2  0.9  2.4  1.4   0.5  24.0     N
# 1        M   26   4.5   62    4.9   3.7  1.4  1.1  2.1   0.6  23.0     N
# 4        M   33   7.1   46    4.9   4.9  1.0  0.8  2.0   0.4  21.0     N
# 5        F   45   2.3   24    4.0   2.9  1.0  1.0  1.5   0.4  21.0     N
# 6        F   50   2.0   50    4.0   3.6  1.3  0.9  2.1   0.6  24.0     N
# ..     ...  ...   ...  ...    ...   ...  ...  ...  ...   ...   ...   ...
# 990      F   57   4.1   70    9.3   5.3  3.3  1.0  1.4   1.3  29.0     Y
# 992      M   55   3.1   39    8.5   5.0  2.5  1.9  2.9   0.7  27.0     Y
# 993      M   28   3.5   61    8.5   4.5  1.9  1.1  2.6   0.8  37.0     Y
# 994      M   69  10.3  185    7.7   4.9  1.9  1.2  3.0   0.7  37.0     Y
# 995      M   71  11.0   97    7.0   7.5  1.7  1.2  1.8   0.6  30.0     Y
#
# [826 rows x 12 columns]

# %% [markdown]
# ## Tratando os dados do dataframe de doenças cardíacas

# %% [markdown]
# ### Ajustando valores

# %%
heart_disease_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1190 entries, 0 to 1189
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   age                  1190 non-null   int64
#  1   sex                  1190 non-null   int64
#  2   chest pain type      1190 non-null   int64
#  3   resting bp s         1190 non-null   int64
#  4   cholesterol          1190 non-null   int64
#  5   fasting blood sugar  1190 non-null   int64
#  6   resting ecg          1190 non-null   int64
#  7   max heart rate       1190 non-null   int64
#  8   exercise angina      1190 non-null   int64
#  9   oldpeak              1190 non-null   float64
#  10  ST slope             1190 non-null   int64
#  11  target               1190 non-null   int64
# dtypes: float64(1), int64(11)
# memory usage: 111.7 KB

# %%
heart_disease_df.sex = (heart_disease_df
                          .sex.replace(1, 'M')
                          .replace(0, 'F'))
heart_disease_df.sex.unique()
# Out:
# array(['M', 'F'], dtype=object)

# %%
heart_disease_df['chest pain type'] = (heart_disease_df['chest pain type']
                                        .replace(1, 'typical angina')
                                        .replace(2, 'atypical angina')
                                        .replace(3, 'non-anginal pain')
                                        .replace(4, 'asymptomatic'))
heart_disease_df['chest pain type'].unique()
# Out:
# array(['atypical angina', 'non-anginal pain', 'asymptomatic',
#        'typical angina'], dtype=object)

# %%
heart_disease_df['fasting blood sugar'] = (heart_disease_df['fasting blood sugar']
                                            .replace(1, True)
                                            .replace(0, False))
heart_disease_df['fasting blood sugar'].unique()
# Out:
# array([False,  True])

# %%
heart_disease_df['resting ecg'] = (heart_disease_df['resting ecg']
                                    .replace(0, 'normal')
                                    .replace(1, 'having ST-T wave abnormality')
                                    .replace(2, 'showing probable or definite left ventricular hypertrophy by Estes\' criteria'))
heart_disease_df['resting ecg'].unique()
# Out:
# array(['normal', 'having ST-T wave abnormality',
#        "showing probable or definite left ventricular hypertrophy by Estes' criteria"],
#       dtype=object)

# %%
heart_disease_df['exercise angina'] = (heart_disease_df['exercise angina']
                                        .replace(1, True)
                                        .replace(0, False))
heart_disease_df['exercise angina'].unique()
# Out:
# array([False,  True])

# %% [markdown]
# #### Foi identificado apenas 1 linha com o valor 0, como demonstrado abaixo. Assim este valor desconhecido deve ser removido do dataframe

# %%
heart_disease_df.groupby('ST slope').count()
# Out:
#           age  sex  chest pain type  resting bp s  cholesterol  \
# ST slope
# 0           1    1                1             1            1
# 1         526  526              526           526          526
# 2         582  582              582           582          582
# 3          81   81               81            81           81
#
#           fasting blood sugar  resting ecg  max heart rate  exercise angina  \
# ST slope
# 0                           1            1               1                1
# 1                         526          526             526              526
# 2                         582          582             582              582
# 3                          81           81              81               81
#
#           oldpeak  target
# ST slope
# 0               1       1
# 1             526     526
# 2             582     582
# 3              81      81

# %%
# Removing unknown value
heart_disease_df = heart_disease_df.loc[ heart_disease_df['ST slope'] != 0]
heart_disease_df['ST slope'] = (heart_disease_df['ST slope']
                                  .replace(1, 'upsloping')
                                  .replace(2, 'flat')
                                  .replace(3, 'downsloping'))
heart_disease_df['ST slope'].unique()
# Out:
# <ipython-input-24-9da12bbb3dd1>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heart_disease_df['ST slope'] = (heart_disease_df['ST slope']
# array(['upsloping', 'flat', 'downsloping'], dtype=object)

# %%
heart_disease_df['target'] = (heart_disease_df['target']
                                .replace(1, 'heart disease')
                                .replace(0, 'normal'))
heart_disease_df['target'].unique()
# Out:
# <ipython-input-25-4b15e05714d9>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heart_disease_df['target'] = (heart_disease_df['target']
# array(['normal', 'heart disease'], dtype=object)

# %%
display(heart_disease_df)
# Out:
#       age sex   chest pain type  resting bp s  cholesterol  \
# 0      40   M   atypical angina           140          289
# 1      49   F  non-anginal pain           160          180
# 2      37   M   atypical angina           130          283
# 3      48   F      asymptomatic           138          214
# 4      54   M  non-anginal pain           150          195
# ...   ...  ..               ...           ...          ...
# 1185   45   M    typical angina           110          264
# 1186   68   M      asymptomatic           144          193
# 1187   57   M      asymptomatic           130          131
# 1188   57   F   atypical angina           130          236
# 1189   38   M  non-anginal pain           138          175
#
#       fasting blood sugar                                        resting ecg  \
# 0                   False                                             normal
# 1                   False                                             normal
# ...

# %% [markdown]
# ### Removendo duplicatas

# %%
heart_disease_df.shape
# Out:
# (1189, 12)

# %%
heart_disease_df = heart_disease_df.drop_duplicates()
heart_disease_df.shape # sem duplicatas
# Out:
# (917, 12)

# %% [markdown]
# ### Removendo valores nulos

# %%
heart_disease_df.isnull().sum()
# Out:
# age                    0
# sex                    0
# chest pain type        0
# resting bp s           0
# cholesterol            0
# fasting blood sugar    0
# resting ecg            0
# max heart rate         0
# exercise angina        0
# oldpeak                0
# ST slope               0
# target                 0
# dtype: int64

# %% [markdown]
# ### Removendo números zerados onde não faz sentido

# %%
heart_disease_numeric_columns = []
for column in heart_disease_df.columns:
  if (heart_disease_df[column].dtype in ['int64', 'float64']): heart_disease_numeric_columns.append(column)
print(heart_disease_numeric_columns)
# Out:
# ['age', 'resting bp s', 'cholesterol', 'max heart rate', 'oldpeak']

# %%
exceptions = ['oldpeak']
for numeric_column in heart_disease_numeric_columns:
  if (numeric_column in exceptions): continue
  without_zeros_df = heart_disease_df[ heart_disease_df[numeric_column] != 0 ]
  heart_disease_df = without_zeros_df

# %%
print(f'\n3 smallest data')
display(heart_disease_df.nsmallest(3, columns=heart_disease_numeric_columns))
print(f'\n3 largest data')
display(heart_disease_df.nlargest(3, columns=heart_disease_numeric_columns))
# Out:
# 3 smallest data
#      age sex  chest pain type  resting bp s  cholesterol  fasting blood sugar  \
# 209   28   M  atypical angina           130          132                False
# 171   29   M  atypical angina           120          243                False
# 831   29   M  atypical angina           130          204                False
#
#                                            resting ecg  max heart rate  \
# 209  showing probable or definite left ventricular ...             185
# 171                                             normal             160
# 831  showing probable or definite left ventricular ...             202
#
#      exercise angina  oldpeak   ST slope  target
# 209            False      0.0  upsloping  normal
# 171            False      0.0  upsloping  normal
# 831            False      0.0  upsloping  normal
# 3 largest data
#      age sex   chest pain type  resting bp s  cholesterol  \
# 816   77   M      asymptomatic           125          304
# ...

# %%
heart_disease_df.min()
# Out:
# age                                              28
# sex                                               F
# chest pain type                        asymptomatic
# resting bp s                                     92
# cholesterol                                      85
# fasting blood sugar                           False
# resting ecg            having ST-T wave abnormality
# max heart rate                                   69
# exercise angina                               False
# oldpeak                                        -0.1
# ST slope                                downsloping
# target                                heart disease
# dtype: object

# %% [markdown]
# ### Visualização final dos dados

# %%
display(heart_disease_df)
# Out:
#       age sex   chest pain type  resting bp s  cholesterol  \
# 0      40   M   atypical angina           140          289
# 1      49   F  non-anginal pain           160          180
# 2      37   M   atypical angina           130          283
# 3      48   F      asymptomatic           138          214
# 4      54   M  non-anginal pain           150          195
# ...   ...  ..               ...           ...          ...
# 1185   45   M    typical angina           110          264
# 1186   68   M      asymptomatic           144          193
# 1187   57   M      asymptomatic           130          131
# 1188   57   F   atypical angina           130          236
# 1189   38   M  non-anginal pain           138          175
#
#       fasting blood sugar                                        resting ecg  \
# 0                   False                                             normal
# 1                   False                                             normal
# ...

# %% [markdown]
# ## Tratando os dados do dataframe de câncer de mama

# %%
breast_cancer_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4024 entries, 0 to 4023
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Age                     4024 non-null   int64
#  1   Race                    4024 non-null   object
#  2   Marital Status          4024 non-null   object
#  3   Unnamed: 3              0 non-null      float64
#  4   T Stage                 4024 non-null   object
#  5   N Stage                 4024 non-null   object
#  6   6th Stage               4024 non-null   object
#  7   Grade                   4024 non-null   object
#  8   A Stage                 4024 non-null   object
#  9   Tumor Size              4024 non-null   int64
#  10  Estrogen Status         4024 non-null   object
#  11  Progesterone Status     4024 non-null   object
#  12  Regional Node Examined  4024 non-null   int64
#  13  Reginol Node Positive   4024 non-null   int64
# ...

# %% [markdown]
# ### Ajustando valores

# %%
breast_cancer_df = breast_cancer_df.drop(columns=['Unnamed: 3']).reset_index(drop=True)

# %%
breast_cancer_df.head()
# Out:
#    Age                                              Race   \
# 0   43  Other (American Indian/AK Native, Asian/Pacifi...
# 1   47  Other (American Indian/AK Native, Asian/Pacifi...
# 2   67                                              White
# 3   46                                              White
# 4   63                                              White
#
#                    Marital Status T Stage  N Stage 6th Stage  \
# 0  Married (including common law)       T2      N3      IIIC
# 1  Married (including common law)       T2      N2      IIIA
# 2  Married (including common law)       T2      N1       IIB
# 3                        Divorced       T1      N1       IIA
# 4  Married (including common law)       T2      N2      IIIA
#
#                                  Grade   A Stage  Tumor Size Estrogen Status  \
# 0  Moderately differentiated; Grade II  Regional          40        Positive
# 1  Moderately differentiated; Grade II  Regional          45        Positive
# ...

# %% [markdown]
# ### Removendo duplicatas

# %%
breast_cancer_df.shape
# Out:
# (4024, 15)

# %%
breast_cancer_df = breast_cancer_df.drop_duplicates()
breast_cancer_df.shape # sem duplicatas
# Out:
# (4023, 15)

# %% [markdown]
# ### Removendo valores nulos

# %%
breast_cancer_df.isnull().sum()
# Out:
# Age                       0
# Race                      0
# Marital Status            0
# T Stage                   0
# N Stage                   0
# 6th Stage                 0
# Grade                     0
# A Stage                   0
# Tumor Size                0
# Estrogen Status           0
# Progesterone Status       0
# Regional Node Examined    0
# Reginol Node Positive     0
# Survival Months           0
# Status                    0
# dtype: int64

# %% [markdown]
# ### Removendo números zerados onde não faz sentido

# %%
breast_cancer_df.min()
# Out:
# Age                                                        30
# Race                                                    Black
# Marital Status                                       Divorced
# T Stage                                                    T1
# N Stage                                                    N1
# 6th Stage                                                 IIA
# Grade                     Moderately differentiated; Grade II
# A Stage                                               Distant
# Tumor Size                                                  1
# Estrogen Status                                      Negative
# Progesterone Status                                  Negative
# Regional Node Examined                                      1
# Reginol Node Positive                                       1
# Survival Months                                             1
# Status                                                  Alive
# dtype: object

# %% [markdown]
# ### Visualização final dos dados

# %%
display(breast_cancer_df)
# Out:
#       Age                                              Race   \
# 0      43  Other (American Indian/AK Native, Asian/Pacifi...
# 1      47  Other (American Indian/AK Native, Asian/Pacifi...
# 2      67                                              White
# 3      46                                              White
# 4      63                                              White
# ...   ...                                                ...
# 4019   52                                              White
# 4020   53                                              White
# 4021   53                                              White
# 4022   60  Other (American Indian/AK Native, Asian/Pacifi...
# 4023   62                                              White
#
#                       Marital Status T Stage  N Stage 6th Stage  \
# 0     Married (including common law)       T2      N3      IIIC
# 1     Married (including common law)       T2      N2      IIIA
# ...

# %% [markdown]
# # Respondendo hipóteses sobre os dados

# %% [markdown]
# ## 1. O gênero está associado à presença de diabetes?

# %% [markdown]
# O "chi-quadrado" (chi-square) é uma medida estatística utilizada para avaliar a dependência entre duas variáveis categóricas. É um teste estatístico não paramétrico que compara a distribuição observada dos dados com a distribuição esperada caso as duas variáveis sejam independentes. O teste qui-quadrado é aplicado para determinar se existe uma associação significativa entre as variáveis categóricas.
#
# Hipótese: `existe uma relação significativa entre Gênero e a Diabetes.`

# %% [markdown]
# Utilizando o teste qui-quadrado (chi-square test), foi criada uma tabela de contingência cruzando as variáveis "Gender" e "CLASS".

# %%
from scipy.stats import chi2_contingency

contingency_table = pd.crosstab(diabetes_df['Gender'], diabetes_df['CLASS'])
print()
contingency_table
# Out:
# CLASS    N   P    Y
# Gender
# F       58  13  292
# M       38  27  398

# %% [markdown]
# Utilizando o teste qui-quadrado e obtendo o valor-p verifica-se se existe uma associação significativa entre o gênero e a presença de diabetes.

# %%
chi2, p_value, _, _ = chi2_contingency(contingency_table)
print(f'p-value: {p_value:.3f}')
# Out:
# p-value: 0.001

# %% [markdown]
# Como o valor-p foi menor que o nível de significância, a hipótese nula é rejeitada, indicando que há evidências para concluir que o gênero está associado à presença de diabetes.

# %%
breast_cancer_df.to_csv('breast_cancer')
heart_disease_df.to_csv('heard_disease')

# %% [markdown]
# ## 2. Qual faixa etária é mais afetada pelas doenças?

# %% [markdown]
# #### Função auxiliar

# %%
import statistics
import matplotlib.pyplot as plt

def barplot_for_disease(disease_column, disease_status, age_column, dataframe, title='Casos por Faixa Etária'):
    # Filtrando apenas os casos de interesse
    diabetes_cases = dataframe[dataframe[disease_column] == disease_status]

    # Contando os casos por faixa etária
    age_counts = diabetes_cases[age_column].value_counts()

    # Ordenando as faixas etárias em ordem crescente
    age_counts = age_counts.sort_index()

    # Criando o gráfico de barras
    plt.bar(age_counts.index, age_counts.values)
    plt.xlabel('Faixa Etária')
    plt.ylabel('Número de Casos')
    plt.title(title)
    plt.tight_layout()
    plt.show()

    return statistics.mode(diabetes_cases[age_column])

# %% [markdown]
# #### Análises

# %%
print(f"\nIdade mais afetada: {barplot_for_disease('CLASS', 'Y', 'AGE', diabetes_df, 'Casos de Diabetes por Faixa Etária')}")
# Out:
# Idade mais afetada: 55

# %%
print(f"\nIdade mais afetada: {barplot_for_disease('target', 'heart disease', 'age', heart_disease_df, 'Casos de doenças cardíacas por Faixa Etária')}")
# Out:
# Idade mais afetada: 58

# %%
print(f"\nIdade mais afetada: {barplot_for_disease('Status', 'Alive', 'Age', breast_cancer_df, 'Quantidade de afetados por câncer por Faixa Etária')}")
# Out:
# Idade mais afetada: 47

# %%
print(f"\nIdade mais afetada: {barplot_for_disease('Status', 'Dead', 'Age', breast_cancer_df, 'Mortes por câncer por Faixa Etária')}")
# Out:
# Idade mais afetada: 69

# %% [markdown]
# Com base na análise do conjunto de dados, observamos que a faixa etária mais afetada pelas doenças é, em média, 53 anos. A diabetes e doenças cardíacas possuem uma idade mais afetada próxima, de 55 e 58 anos respectivamente, equanto o câncer afeta mais pessoas por volta de 47 anos e a morte por câncer é mais comum aos 69 anos.

# %% [markdown]
# ## 3. Por faixa etária, as doenças são mais comuns em homens ou mulheres?

# %% [markdown]
# #### Função auxiliar

# %%
def plot_disease_by_gender_and_age(disease_column, disease_status, gender_column, female_identifier, male_identifier, age_column, dataframe, title='Casos de Doenças por Faixa Etária e Gênero'):
    """
    Returns:
        Uma tupla contendo a moda das idades para mulheres e homens afetados.
    """
    # Filtrando apenas os casos de interesse
    disease_cases = dataframe[dataframe[disease_column] == disease_status]

    # Agrupando por faixa etária e gênero e contando os casos
    age_gender_counts = disease_cases.groupby([age_column, gender_column]).size().unstack()

    # Ordenando as faixas etárias em ordem crescente
    age_gender_counts = age_gender_counts.sort_index()

    # Criando o gráfico de barras empilhadas
    age_gender_counts.plot(kind='bar', stacked=True)
    plt.xlabel('Faixa Etária')
    plt.ylabel('Número de Casos')
    plt.title(title)
    plt.legend(title='Gênero')

    x_ticks = np.arange(0, len(age_gender_counts.index), 5)
    plt.xticks(x_ticks, age_gender_counts.index[x_ticks], rotation=45, ha='right')

    plt.tight_layout()
    plt.autoscale()
    plt.show()
    
    male_mode = statistics.mode(disease_cases[disease_cases[gender_column] == male_identifier][age_column])
    female_mode = statistics.mode(disease_cases[disease_cases[gender_column] == female_identifier][age_column])

    return female_mode, male_mode

# %% [markdown]
# #### Análises

# %%
modes = plot_disease_by_gender_and_age(
    'CLASS', 'Y',
    'Gender', 'F', 'M',
    'AGE',
    diabetes_df,
    'Diabetes por faixa etária e por gênero'
)

print(f"\nIdade mais afetada entre homens: {modes[1]}\nIdade mais afetada entre mulheres: {modes[0]}")
# Out:
# Idade mais afetada entre homens: 55
# Idade mais afetada entre mulheres: 55

# %%
modes = plot_disease_by_gender_and_age(
    'target', 'heart disease',
    'sex', 'F', 'M',
    'age',
    heart_disease_df,
    'Doenças cardíacas por faixa etária e por gênero'
)

print(f"\nIdade mais afetada entre homens: {modes[1]}\nIdade mais afetada entre mulheres: {modes[0]}")
# Out:
# Idade mais afetada entre homens: 58
# Idade mais afetada entre mulheres: 62

# %% [markdown]
# Com base na análise dos dados, podemos concluir que tanto homens quanto mulheres apresentam uma incidência semelhante de diabetes (55 anos mais afetados) por idade.
#
# Por outro lado, no caso das doenças cardíacas, identificamos uma diferença nas idades mais afetadas entre homens e mulheres. Enquanto a idade mais comum para homens foi de 58 anos, para mulheres foi de 62 anos. Isso sugere que as doenças cardíacas podem ter um impacto mais tardio nas mulheres em comparação aos homens.

# %% [markdown]
# ## 4. Existem relações entre as variáveis dos datasets?

# %% [markdown]
# #### Função Auxiliar

# %% [markdown]
# O KBest calcula a relação entre as variáveis usando uma funçāo, como de regressāo, Chi-quadrado, ANOVA, etc e faz um ranking entre as váriaveis mais relevantes para o calculo de uma determinada variável. Nessa caso foi utilizado a funçāo ANOVA para medir a significancia das variaveis dos casos de doenças.
# ANOVA é um analise estatistica que permite comparar a significancia das variaveis independentes para um variavel dependente.

# %%
from sklearn.feature_selection import SelectKBest, f_classif
from sklearn.preprocessing import LabelEncoder
import pandas as pd


def encode(data: pd.DataFrame):
  return pd.get_dummies(data)

def relation_between_variables(df: pd.DataFrame, target: str, verbose=False):
  # Separate the features (X) and the target variable (y)
  data = encode(df)
  reuslts_by_target = []
  target_columns = [colunm for colunm in data.columns if colunm.startswith(target)]
  for col in target_columns:
            # avalia o score para o target


            
            X = data.drop(columns=target_columns)
            y = data[col]

            # Create an instance of SelectKBest with the desired scoring function
            kbest = SelectKBest(score_func=f_classif, k='all')  # 'all' selects all features, or specify the desired number

            # Fit the SelectKBest instance on the features and target variable
            kbest.fit(X, y)

            # Get the scores and p-values for each feature
            scores = kbest.scores_
            p_values = kbest.pvalues_

            # Create a DataFrame to display the scores and p-values
            p_values_result = ['Significativo' if (item < 0.05) else 'Irrelevante' for item in p_values ]
            results = pd.DataFrame({'Feature': X.columns, 'Score': scores, 'p-value': p_values_result})
            results.sort_values(by='Score', ascending=False, inplace=True)
            reuslts_by_target.append((results.reset_index(drop=True), col))

  target_classes = len(reuslts_by_target)
  avgs_by_variable = {}
  first_execution = False
  for data, target in reuslts_by_target:
      if (verbose):
        print(f'{target}\n')
        display(data)
        print('\n')
      if (not first_execution):
        first_execution = True
        for i, feature in enumerate(data['Feature']):
          avgs_by_variable[feature] = data['Score'][i]
      else:
        for i, feature in enumerate(data['Feature']):
          avgs_by_variable[feature] += data['Score'][i]
  for key in avgs_by_variable:
    avgs_by_variable[key] /= target_classes
    avgs_by_variable[key] = round(avgs_by_variable[key], 2)
  avgs_by_variable = dict(sorted(avgs_by_variable.items(), key=lambda item: item[1], reverse=True))
  if (verbose):
    print('\nMédia dos Scores\n')
    print(f'{avgs_by_variable}\n')

  return reuslts_by_target

# %% [markdown]
# #### Análises

# %%
result = relation_between_variables(diabetes_df, 'CLASS', verbose=True)
# Out:
# CLASS_N
#      Feature       Score        p-value
# 0      HbA1c  309.572591  Significativo
# 1        BMI  299.442501  Significativo
# 2        AGE  138.888660  Significativo
# 3       Chol   30.508714  Significativo
# 4         TG   29.230057  Significativo
# 5   Gender_F   12.107848  Significativo
# 6   Gender_M   12.107848  Significativo
# 7       VLDL    5.732191  Significativo
# 8       Urea    2.264494    Irrelevante
# 9         Cr    1.024768    Irrelevante
# 10       LDL    0.097150    Irrelevante
# 11       HDL    0.000028    Irrelevante
# CLASS_P
#      Feature      Score        p-value
# 0        AGE  59.041494  Significativo
# 1        BMI  51.052736  Significativo
# 2      HbA1c  34.578028  Significativo
# 3       Chol   5.359001  Significativo
# 4   Gender_F   2.236543    Irrelevante
# 5   Gender_M   2.236543    Irrelevante
# 6       VLDL   2.000998    Irrelevante
# 7       Urea   1.817520    Irrelevante
# 8        LDL   1.587289    Irrelevante
# ...

# %%
result = relation_between_variables(heart_disease_df, 'target', verbose=True)
# Out:
# target_heart disease
#                                               Feature       Score  \
# 0                                  ST slope_upsloping  553.255197
# 1                                       ST slope_flat  398.707824
# 2                                     exercise angina  328.309271
# 3                        chest pain type_asymptomatic  282.873228
# 4                                             oldpeak  244.356991
# 5                                      max heart rate  123.132917
# 6                     chest pain type_atypical angina  121.755492
# 7                                                 age   71.935179
# 8                                               sex_M   69.390521
# 9                                               sex_F   69.390521
# 10                   chest pain type_non-anginal pain   39.777775
# 11                                       resting bp s   22.677821
# 12                                fasting blood sugar   19.049488
# ...

# %%
result = relation_between_variables(breast_cancer_df, 'Status', verbose=True)
# Out:
# Status_Alive
#                                               Feature        Score  \
# 0                                     Survival Months  1181.944829
# 1                               Reginol Node Positive   283.396257
# 2                                          N Stage_N3   231.289946
# 3                                      6th Stage_IIIC   231.289946
# 4                                          N Stage_N1   202.660832
# 5                            Estrogen Status_Positive   141.902736
# 6                            Estrogen Status_Negative   141.902736
# 7                        Progesterone Status_Positive   130.108090
# 8                        Progesterone Status_Negative   130.108090
# 9                                       6th Stage_IIA    96.239925
# 10             Grade_Poorly differentiated; Grade III    84.427425
# 11                                         Tumor Size    73.686124
# 12                                        T Stage _T1    63.314961
# ...

# %% [markdown]
# Pelos dados podemos observar como a massa corporal e o açucar médio no sangue são váriaveis importantes para a classificação da diabete como positivo, negativo, ou diabetes previsível. A idade também parece ser um fator bem relavante para a classificação da diabetes.
#
# No casos de doença de coração é possível analisar a relevância da inclinação do ST. ST representa o começo da repolarização ventricular. Um grafico de ST normal deveria ser neutro (um gráfico com uma reta horizontal, podendo ter um pouco de inclinação para cima ou para baixo). Outro atributo relevante para analise de possibilidade de doença cardiaca parece ser a presença de angina(dor no coração) após exercicios físicos.
# Em comparação com a diabetes, é possível perceber como os valores de colesterol, acuçar no sange e idade são váriaveis muito importantes, enquanto em relação as doenças cardiacas não parecem ter muito efeito.
#
# Para os casos de cancer de mama, como esperado, o estado do cancer como regional ou disperso(localiado em uma parte do corpo ou espalhado pelo corpo) é um grande fator para classificar as chances de vida, assim como a classificaçao do estagio do cancêr.

# %% [markdown]
# ## 5. Qual é a idade com maior incidência de câncer de mama por raça?

# %% [markdown]
# #### Função auxiliar

# %%
def plot_disease_by_age_and_race(disease_column, disease_status, race_column, age_column, dataframe, title='Casos de Doenças por Faixa Etária e Raça', label='Raça'):
    """
    Plota um gráfico de barras empilhadas mostrando o número de casos de uma doença por faixa etária e raça.

    Parameters:
        disease_column (str): Nome da coluna que contém a informação sobre a doença.
        disease_status (str): Valor que indica o status da doença a ser considerado.
        race_column (str): Nome da coluna que contém a informação sobre a raça.
        age_column (str): Nome da coluna que contém a informação sobre a faixa etária.
        dataframe (pd.DataFrame): O DataFrame que contém os dados.
        title (str): Título do gráfico.

    Returns:
        Uma tuple contendo a moda das idades para cada raça Black, Other e White.
    """
    # Filtrando apenas os casos de interesse
    disease_cases = dataframe[dataframe[disease_column] == disease_status]

    # Agrupando por faixa etária e raça e contando os casos
    age_race_counts = disease_cases.groupby([age_column, race_column]).size().unstack()

    # Ordenando as faixas etárias em ordem crescente
    age_race_counts = age_race_counts.sort_index()

    # Criando o gráfico de barras empilhadas
    age_race_counts.plot(kind='bar', stacked=True, alpha=0.9)
    plt.xlabel('Faixa Etária')
    plt.ylabel('Número de Casos')
    plt.title(title)
    plt.legend(title=label)

    x_ticks = range(0, len(age_race_counts.index), 5)
    plt.xticks(x_ticks, age_race_counts.index[x_ticks], rotation=45, ha='right')

    plt.tight_layout()
    plt.autoscale()
    plt.show()

    # Calculando a moda das idades por raça
    race_modes = []
    for race in age_race_counts.columns:
        race_modes.append(statistics.mode(disease_cases[disease_cases[race_column] == race][age_column]))

    return tuple(race_modes)

# %% [markdown]
# #### Análise

# %%
print(f"\nIdades mais afetadas por raça (Black, Other, White): {plot_disease_by_age_and_race('Status', 'Alive', 'Race ', 'Age', breast_cancer_df, 'Quantidade de afetados por câncer por Raça')}")
# Out:
# Idades mais afetadas por raça (Black, Other, White): (46, 48, 47)

# %% [markdown]
# Com base na análise dos dados, podemos observar que as idades mais afetadas variam levemente entre as diferentes raças:
#
# Para indivíduos Pretos, a idade mais comum de afetação é de 46 anos.
#
# Para indivíduos Brancos, a idade mais prevalente é de 47 anos.
#
# Já para Outras a idade mais afetada é de 48 anos.
#
# Assim, é possível concluir que a idade mais frequente de câncer de mama é praticamente a mesma independentemente da raça analisada.

# %% [markdown]
# ## 6. Existe diferença de idade onde o câncer é mais comum por estado civil?

# %%
print(f"\nIdades mais afetadas por casamento (Divorciado, Casado, Separado, Solteiro, Viúvo): {plot_disease_by_age_and_race('Status', 'Alive', 'Marital Status', 'Age', breast_cancer_df, 'Quantidade de afetados por câncer de mama por Estado civil por idade', 'Estado civil')}")
# Out:
# Idades mais afetadas por casamento (Divorciado, Casado, Separado, Solteiro, Viúvo): (59, 47, 54, 48, 67)

# %% [markdown]
# É possível observar que há uma associação entre o estado civil e a idade onde o câncer de mama é mais comum.
#
# Inicialmente, os viúvos apresentam uma maior idade onde a doença é mais comum, mas é importante considerar que eles provavelmente se tornam viúvos em idades mais avançadas, o que pode explicar esse padrão. Notavelmente, o câncer de mama é mais comum aos 67 anos nesse grupo.
#
# Ao excluirmos os viúvos da análise, observamos que os divorciados ocupam o segundo lugar, com a idade mais frequente de 59 anos, seguidos pelos separados, com 54 anos.
#
# Por outro lado, os casados e solteiros apresentam menor idade em que o câncer de mama é mais comum, sendo elas de 47 e 48 anos, respectivamente. Esses resultados sugerem que o estado civil pode desempenhar um papel na idade mais comum em que o câncer de mama é encontrado.
